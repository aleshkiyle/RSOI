# %%
import pickle
import xmlrpc.client

import matplotlib.pyplot
from PIL import Image
from pylab import *

server = xmlrpc.client.ServerProxy("http://localhost:8071")


def binarizate_image(image_array, limit):
    pickle_image = pickle.dumps(image_array)
    binary_image = xmlrpc.client.Binary(pickle_image)
    response = server.image_binarization_by_limit(binary_image, limit)
    binarizated_image_array = pickle.loads(response.data)
    return binarizated_image_array


# Монохромное изображение
monochrome_image = Image.open('resources/11.bmp')
monochrome_image_array = array(monochrome_image)
matplotlib.pyplot.imshow(monochrome_image_array, cmap="gray")
matplotlib.pyplot.show()

binarizated_monochrome_image_array = binarizate_image(monochrome_image_array, 50)
matplotlib.pyplot.imshow(binarizated_monochrome_image_array, cmap="gray")
matplotlib.pyplot.show()

binarizated_monochrome_image_array = binarizate_image(monochrome_image_array, 128)
matplotlib.pyplot.imshow(binarizated_monochrome_image_array, cmap="gray")
matplotlib.pyplot.show()

binarizated_monochrome_image_array = binarizate_image(monochrome_image_array, 250)
matplotlib.pyplot.imshow(binarizated_monochrome_image_array, cmap="gray")
matplotlib.pyplot.show()

# Цветное изображение
color_image = Image.open('resources/Jellyfish.jpg')
color_image_array = array(color_image)
matplotlib.pyplot.imshow(color_image, cmap="gray")
matplotlib.pyplot.show()

binarizated_color_image_array = binarizate_image(color_image_array, 50)
matplotlib.pyplot.imshow(binarizated_color_image_array, cmap="gray")
matplotlib.pyplot.show()

binarizated_color_image_array = binarizate_image(color_image_array, 128)
matplotlib.pyplot.imshow(binarizated_color_image_array, cmap="gray")
matplotlib.pyplot.show()

binarizated_color_image_array = binarizate_image(color_image_array, 250)
matplotlib.pyplot.imshow(binarizated_color_image_array, cmap="gray")
matplotlib.pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# Cell In[1], line 25
#      22 matplotlib.pyplot.imshow(monochrome_image_array, cmap="gray")
#      23 matplotlib.pyplot.show()
# ---> 25 binarizated_monochrome_image_array = binarizate_image(monochrome_image_array, 50)
#      26 matplotlib.pyplot.imshow(binarizated_monochrome_image_array, cmap="gray")
#      27 matplotlib.pyplot.show()
#
# Cell In[1], line 14, in binarizate_image(image_array, limit)
#      12 pickle_image = pickle.dumps(image_array)
#      13 binary_image = xmlrpc.client.Binary(pickle_image)
# ---> 14 response = server.image_binarization_by_limit(binary_image, limit)
#      15 binarizated_image_array = pickle.loads(response.data)
#      16 return binarizated_image_array
#
# File ~\anaconda3\Lib\xmlrpc\client.py:1122, in _Method.__call__(self, *args)
#    1121 def __call__(self, *args):
# -> 1122     return self.__send(self.__name, args)
#
# File ~\anaconda3\Lib\xmlrpc\client.py:1464, in ServerProxy.__request(self, methodname, params)
#    1458 def __request(self, methodname, params):
#    1459     # call a method on the remote server
#    1461     request = dumps(params, methodname, encoding=self.__encoding,
#    1462                     allow_none=self.__allow_none).encode(self.__encoding, 'xmlcharrefreplace')
# -> 1464     response = self.__transport.request(
#    1465         self.__host,
#    1466         self.__handler,
#    1467         request,
#    1468         verbose=self.__verbose
#    1469         )
#    1471     if len(response) == 1:
#    1472         response = response[0]
#
# File ~\anaconda3\Lib\xmlrpc\client.py:1166, in Transport.request(self, host, handler, request_body, verbose)
#    1164 for i in (0, 1):
#    1165     try:
# -> 1166         return self.single_request(host, handler, request_body, verbose)
#    1167     except http.client.RemoteDisconnected:
#    1168         if i:
#
# File ~\anaconda3\Lib\xmlrpc\client.py:1178, in Transport.single_request(self, host, handler, request_body, verbose)
#    1175 def single_request(self, host, handler, request_body, verbose=False):
#    1176     # issue XML-RPC request
#    1177     try:
# -> 1178         http_conn = self.send_request(host, handler, request_body, verbose)
#    1179         resp = http_conn.getresponse()
#    1180         if resp.status == 200:
#
# File ~\anaconda3\Lib\xmlrpc\client.py:1291, in Transport.send_request(self, host, handler, request_body, debug)
#    1289 headers.append(("User-Agent", self.user_agent))
#    1290 self.send_headers(connection, headers)
# -> 1291 self.send_content(connection, request_body)
#    1292 return connection
#
# File ~\anaconda3\Lib\xmlrpc\client.py:1321, in Transport.send_content(self, connection, request_body)
#    1318     request_body = gzip_encode(request_body)
#    1320 connection.putheader("Content-Length", str(len(request_body)))
# -> 1321 connection.endheaders(request_body)
#
# File ~\anaconda3\Lib\http\client.py:1281, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1279 else:
#    1280     raise CannotSendHeader()
# -> 1281 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~\anaconda3\Lib\http\client.py:1041, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1039 msg = b"\r\n".join(self._buffer)
#    1040 del self._buffer[:]
# -> 1041 self.send(msg)
#    1043 if message_body is not None:
#    1044
#    1045     # create a consistent interface to message_body
#    1046     if hasattr(message_body, 'read'):
#    1047         # Let file-like take precedence over byte-like.  This
#    1048         # is needed to allow the current position of mmap'ed
#    1049         # files to be taken into account.
#
# File ~\anaconda3\Lib\http\client.py:979, in HTTPConnection.send(self, data)
#     977 if self.sock is None:
#     978     if self.auto_open:
# --> 979         self.connect()
#     980     else:
#     981         raise NotConnected()
#
# File ~\anaconda3\Lib\http\client.py:945, in HTTPConnection.connect(self)
#     943 """Connect to the host and port specified in __init__."""
#     944 sys.audit("http.client.connect", self, self.host, self.port)
# --> 945 self.sock = self._create_connection(
#     946     (self.host,self.port), self.timeout, self.source_address)
#     947 # Might fail in OSs that don't implement TCP_NODELAY
#     948 try:
#
# File ~\anaconda3\Lib\socket.py:851, in create_connection(address, timeout, source_address, all_errors)
#     849 try:
#     850     if not all_errors:
# --> 851         raise exceptions[0]
#     852     raise ExceptionGroup("create_connection failed", exceptions)
#     853 finally:
#     854     # Break explicitly a reference cycle
#
# File ~\anaconda3\Lib\socket.py:836, in create_connection(address, timeout, source_address, all_errors)
#     834 if source_address:
#     835     sock.bind(source_address)
# --> 836 sock.connect(sa)
#     837 # Break explicitly a reference cycle
#     838 exceptions.clear()
#
# ConnectionRefusedError: [WinError 10061] Подключение не установлено, т.к. конечный компьютер отверг запрос на подключение
